# %% [markdown]
# # Materailised Joins

# %% [markdown]
# ## 0. Necessary imports and setups

# %%
from IPython.display import Image
from IPython.core.display import HTML
# %load_ext sql
# %sql postgresql://appdev@data:5432/appdev
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: appdev@appdev'

# %% [markdown]
# ## 1. On the table "circuits", report:

# %% [markdown]
# ###          What type of indexes exists for the table and why they are of that type (and not some other type):

# %% [markdown]
# To find all the indexes for a specific table I use the following command in psql: "\d+ f1db.circuits" where we get the following:

# %%
# %%html
# <img src = "https://raw.githubusercontent.com/MartinH5/Materialised-Joins/master/Nummer1.PNG">
# Out:
# <img src = "https://raw.githubusercontent.com/MartinH5/Materialised-Joins/master/Nummer1.PNG">

# %% [markdown]
# Here we can see 3 indexes:
#
# idx_17102_primary of the type btree,
#
# idx_17102_url also with the type of btree
#
# circuits_position_idx of the type gist.
#
#
# bTree is a prefered structure for building indexing in database and is quite efficient at it.
# The gist, or Generalised Search Tree, is a versatile search structure, which allows us to build on whichever type we choose. Gist uses <key, pointer> pairs unlike the B-tree which uses integers.
#
# If we inspect each of the indexes we get the following sizes:

# %%
# %%html
# <img src = "https://raw.githubusercontent.com/MartinH5/Materialised-Joins/master/Nummer2.PNG">
# Out:
# <img src = "https://raw.githubusercontent.com/MartinH5/Materialised-Joins/master/Nummer2.PNG">

# %% [markdown]
# ## 2. Write a query that finds the winner of all the races, but only if they are younger than 38 years. The query should give return the date, driver surname, driver age, track time in milliseconds, race name and circuit name for all races.

# %%
# %%sql
# SELECT
# circuits.name AS Circuit_Name,
# races.name AS race_name, races.date AS race_date,
# drivers.surname AS driver_surname, drivers.dob AS driver_birthdate,
# results.milliseconds AS tracktime_ms FROM results
# JOIN drivers ON drivers.driverid = results.driverid AND drivers.dob > '1980-03-19' AND results.position = 1
# JOIN races ON races.raceid = results.raceid
# JOIN circuits ON circuits.circuitid = races.circuitid
# ORDER BY drivers.dob;
# Out:
# 184 rows affected.
# [('Istanbul Park', 'Turkish Grand Prix', datetime.date(2008, 5, 11), 'Massa', datetime.date(1981, 4, 25), 5209451),
#  ('Autódromo José Carlos Pace', 'Brazilian Grand Prix', datetime.date(2006, 10, 22), 'Massa', datetime.date(1981, 4, 25), 5513751),
#  ('Valencia Street Circuit', 'European Grand Prix', datetime.date(2008, 8, 24), 'Massa', datetime.date(1981, 4, 25), 5732339),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2007, 4, 15), 'Massa', datetime.date(1981, 4, 25), 5607515),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2008, 9, 7), 'Massa', datetime.date(1981, 4, 25), 4979394),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2007, 5, 13), 'Massa', datetime.date(1981, 4, 25), 5496230),
#  ('Istanbul Park', 'Turkish Grand Prix', datetime.date(2006, 8, 27), 'Massa', datetime.date(1981, 4, 25), 5331082),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2008, 4, 6), 'Massa', datetime.date(1981, 4, 25), 5466970),
#  ('Circuit de Nevers Magny-Cours', 'French Grand Prix', datetime.date(2008, 6, 22), 'Massa', datetime.date(1981, 4, 25), 5510245),
#  ('Autódromo José Carlos Pace', 'Brazilian Grand Prix', datetime.date(2008, 11, 2), 'Massa', datetime.date(1981, 4, 25), 5651435),
#  ('Istanbul Park', 'Turkish Grand Prix', datetime.date(2007, 8, 26), 'Massa', datetime.date(1981, 4, 25), 5202161),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2006, 5, 28), 'Alonso', datetime.date(1981, 7, 29), 6223116),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2006, 6, 11), 'Alonso', datetime.date(1981, 7, 29), 5151927),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2006, 6, 25), 'Alonso', datetime.date(1981, 7, 29), 5677308),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2011, 7, 10), 'Alonso', datetime.date(1981, 7, 29), 5321196),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2006, 10, 8), 'Alonso', datetime.date(1981, 7, 29), 5032413),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2005, 3, 20), 'Alonso', datetime.date(1981, 7, 29), 5493736),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2005, 4, 3), 'Alonso', datetime.date(1981, 7, 29), 5358531),
#  ('Autodromo Enzo e Dino Ferrari', 'San Marino Grand Prix', datetime.date(2005, 4, 24), 'Alonso', datetime.date(1981, 7, 29), 5261921),
#  ('Nürburgring', 'European Grand Prix', datetime.date(2005, 5, 29), 'Alonso', datetime.date(1981, 7, 29), 5506648),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2012, 3, 25), 'Alonso', datetime.date(1981, 7, 29), 9891812),
#  ('Circuit de Nevers Magny-Cours', 'French Grand Prix', datetime.date(2005, 7, 3), 'Alonso', datetime.date(1981, 7, 29), 5482232),
#  ('Hockenheimring', 'German Grand Prix', datetime.date(2005, 7, 24), 'Alonso', datetime.date(1981, 7, 29), 5188599),
#  ('Valencia Street Circuit', 'European Grand Prix', datetime.date(2012, 6, 24), 'Alonso', datetime.date(1981, 7, 29), 6256649),
#  ('Hockenheimring', 'German Grand Prix', datetime.date(2012, 7, 22), 'Alonso', datetime.date(1981, 7, 29), 5465862),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2005, 10, 16), 'Alonso', datetime.date(1981, 7, 29), 5993618),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2003, 8, 24), 'Alonso', datetime.date(1981, 7, 29), 5941460),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2008, 9, 28), 'Alonso', datetime.date(1981, 7, 29), 7036304),
#  ('Fuji Speedway', 'Japanese Grand Prix', datetime.date(2008, 10, 12), 'Alonso', datetime.date(1981, 7, 29), 5421892),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2007, 4, 8), 'Alonso', datetime.date(1981, 7, 29), 5534930),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2013, 5, 12), 'Alonso', datetime.date(1981, 7, 29), 5956596),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2007, 5, 27), 'Alonso', datetime.date(1981, 7, 29), 6029329),
#  ('Hockenheimring', 'German Grand Prix', datetime.date(2010, 7, 25), 'Alonso', datetime.date(1981, 7, 29), 5258864),
#  ('Nürburgring', 'European Grand Prix', datetime.date(2007, 7, 22), 'Alonso', datetime.date(1981, 7, 29), 7586358),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2010, 9, 12), 'Alonso', datetime.date(1981, 7, 29), 4584572),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2010, 9, 26), 'Alonso', datetime.date(1981, 7, 29), 7073579),
#  ('Korean International Circuit', 'Korean Grand Prix', datetime.date(2010, 10, 24), 'Alonso', datetime.date(1981, 7, 29), 10100810),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2007, 9, 9), 'Alonso', datetime.date(1981, 7, 29), 4717806),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2006, 3, 12), 'Alonso', datetime.date(1981, 7, 29), 5386205),
#  ('Albert Park Grand Prix Circuit', 'Australian Grand Prix', datetime.date(2006, 4, 2), 'Alonso', datetime.date(1981, 7, 29), 5667870),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2006, 5, 14), 'Alonso', datetime.date(1981, 7, 29), 5181759),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2013, 4, 14), 'Alonso', datetime.date(1981, 7, 29), 5786945),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2010, 3, 14), 'Alonso', datetime.date(1981, 7, 29), 5960396),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2008, 8, 3), 'Kovalainen', datetime.date(1981, 10, 19), 5847067),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2008, 6, 8), 'Kubica', datetime.date(1984, 12, 7), 5784227),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2015, 7, 5), 'Hamilton', datetime.date(1985, 1, 7), 5487729),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2015, 6, 7), 'Hamilton', datetime.date(1985, 1, 7), 5513145),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2015, 4, 19), 'Hamilton', datetime.date(1985, 1, 7), 5705809),
#  ('Circuit of the Americas', 'United States Grand Prix', datetime.date(2012, 11, 18), 'Hamilton', datetime.date(1985, 1, 7), 5755269),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2015, 4, 12), 'Hamilton', datetime.date(1985, 1, 7), 5982008),
#  ('Albert Park Grand Prix Circuit', 'Australian Grand Prix', datetime.date(2015, 3, 15), 'Hamilton', datetime.date(1985, 1, 7), 5514067),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2014, 7, 6), 'Hamilton', datetime.date(1985, 1, 7), 8812094),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2014, 4, 20), 'Hamilton', datetime.date(1985, 1, 7), 5608338),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2014, 4, 6), 'Hamilton', datetime.date(1985, 1, 7), 5982743),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2014, 3, 30), 'Hamilton', datetime.date(1985, 1, 7), 6025974),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2008, 7, 6), 'Hamilton', datetime.date(1985, 1, 7), 5949440),
#  ('Hockenheimring', 'German Grand Prix', datetime.date(2008, 7, 20), 'Hamilton', datetime.date(1985, 1, 7), 5480874),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2017, 9, 17), 'Hamilton', datetime.date(1985, 1, 7), 7403544),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2008, 10, 19), 'Hamilton', datetime.date(1985, 1, 7), 5517403),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2007, 6, 10), 'Hamilton', datetime.date(1985, 1, 7), 6251292),
#  ('Indianapolis Motor Speedway', 'United States Grand Prix', datetime.date(2007, 6, 17), 'Hamilton', datetime.date(1985, 1, 7), 5469965),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2007, 8, 5), 'Hamilton', datetime.date(1985, 1, 7), 5752991),
#  ('Fuji Speedway', 'Japanese Grand Prix', datetime.date(2007, 9, 30), 'Hamilton', datetime.date(1985, 1, 7), 7234579),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2017, 9, 3), 'Hamilton', datetime.date(1985, 1, 7), 4532312),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2017, 8, 27), 'Hamilton', datetime.date(1985, 1, 7), 5082820),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2009, 7, 26), 'Hamilton', datetime.date(1985, 1, 7), 5903876),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2009, 9, 27), 'Hamilton', datetime.date(1985, 1, 7), 6966337),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2017, 7, 16), 'Hamilton', datetime.date(1985, 1, 7), 4887430),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2017, 6, 11), 'Hamilton', datetime.date(1985, 1, 7), 5585154),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2017, 5, 14), 'Hamilton', datetime.date(1985, 1, 7), 5756497),
#  ('Istanbul Park', 'Turkish Grand Prix', datetime.date(2010, 5, 30), 'Hamilton', datetime.date(1985, 1, 7), 5327620),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2010, 6, 13), 'Hamilton', datetime.date(1985, 1, 7), 5633456),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2017, 4, 9), 'Hamilton', datetime.date(1985, 1, 7), 5856158),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2010, 8, 29), 'Hamilton', datetime.date(1985, 1, 7), 5344268),
#  ('Yas Marina Circuit', 'Abu Dhabi Grand Prix', datetime.date(2016, 11, 27), 'Hamilton', datetime.date(1985, 1, 7), 5884013),
#  ('Autódromo José Carlos Pace', 'Brazilian Grand Prix', datetime.date(2016, 11, 13), 'Hamilton', datetime.date(1985, 1, 7), 10861335),
#  ('Autódromo Hermanos Rodríguez', 'Mexican Grand Prix', datetime.date(2016, 10, 30), 'Hamilton', datetime.date(1985, 1, 7), 6031402),
#  ('Circuit of the Americas', 'United States Grand Prix', datetime.date(2016, 10, 23), 'Hamilton', datetime.date(1985, 1, 7), 5892618),
#  ('Albert Park Grand Prix Circuit', 'Australian Grand Prix', datetime.date(2008, 3, 16), 'Hamilton', datetime.date(1985, 1, 7), 5690616),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2011, 4, 17), 'Hamilton', datetime.date(1985, 1, 7), 5818226),
#  ('Hockenheimring', 'German Grand Prix', datetime.date(2016, 7, 31), 'Hamilton', datetime.date(1985, 1, 7), 5444200),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2016, 7, 24), 'Hamilton', datetime.date(1985, 1, 7), 6030115),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2016, 7, 10), 'Hamilton', datetime.date(1985, 1, 7), 5695831),
#  ('Red Bull Ring', 'Austrian Grand Prix', datetime.date(2016, 7, 3), 'Hamilton', datetime.date(1985, 1, 7), 5258107),
#  ('Nürburgring', 'German Grand Prix', datetime.date(2011, 7, 24), 'Hamilton', datetime.date(1985, 1, 7), 5850334),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2016, 6, 12), 'Hamilton', datetime.date(1985, 1, 7), 5465296),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2016, 5, 29), 'Hamilton', datetime.date(1985, 1, 7), 7169133),
#  ('Circuit of the Americas', 'United States Grand Prix', datetime.date(2015, 10, 25), 'Hamilton', datetime.date(1985, 1, 7), 6652703),
#  ('Sochi Autodrom', 'Russian Grand Prix', datetime.date(2015, 10, 11), 'Hamilton', datetime.date(1985, 1, 7), 5831024),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2015, 9, 27), 'Hamilton', datetime.date(1985, 1, 7), None),
#  ('Yas Marina Circuit', 'Abu Dhabi Grand Prix', datetime.date(2011, 11, 13), 'Hamilton', datetime.date(1985, 1, 7), 5831886),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2015, 9, 6), 'Hamilton', datetime.date(1985, 1, 7), 4680688),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2012, 6, 10), 'Hamilton', datetime.date(1985, 1, 7), 5549586),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2012, 7, 29), 'Hamilton', datetime.date(1985, 1, 7), 6065503),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2012, 9, 9), 'Hamilton', datetime.date(1985, 1, 7), 4781221),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2015, 8, 23), 'Hamilton', datetime.date(1985, 1, 7), 5020387),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2014, 5, 11), 'Hamilton', datetime.date(1985, 1, 7), 6065155),
#  ('Yas Marina Circuit', 'Abu Dhabi Grand Prix', datetime.date(2014, 11, 23), 'Hamilton', datetime.date(1985, 1, 7), 5942619),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2008, 5, 25), 'Hamilton', datetime.date(1985, 1, 7), 7242742),
#  ('Circuit of the Americas', 'United States Grand Prix', datetime.date(2014, 11, 2), 'Hamilton', datetime.date(1985, 1, 7), 6004785),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2013, 7, 28), 'Hamilton', datetime.date(1985, 1, 7), 6149445),
#  ('Sochi Autodrom', 'Russian Grand Prix', datetime.date(2014, 10, 12), 'Hamilton', datetime.date(1985, 1, 7), 5510744),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2014, 10, 5), 'Hamilton', datetime.date(1985, 1, 7), 6703021),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2014, 9, 21), 'Hamilton', datetime.date(1985, 1, 7), 7204795),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2014, 9, 7), 'Hamilton', datetime.date(1985, 1, 7), 4750236),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2012, 5, 13), 'Maldonado', datetime.date(1985, 3, 9), 5949145),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2016, 8, 28), 'Rosberg', datetime.date(1985, 6, 27), 6291058),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2012, 4, 15), 'Rosberg', datetime.date(1985, 6, 27), 5786929),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2013, 5, 26), 'Rosberg', datetime.date(1985, 6, 27), 8272056),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2013, 6, 30), 'Rosberg', datetime.date(1985, 6, 27), 5579456),
#  ('Albert Park Grand Prix Circuit', 'Australian Grand Prix', datetime.date(2014, 3, 16), 'Rosberg', datetime.date(1985, 6, 27), 5578710),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2014, 5, 25), 'Rosberg', datetime.date(1985, 6, 27), 6567661),
#  ('Red Bull Ring', 'Austrian Grand Prix', datetime.date(2014, 6, 22), 'Rosberg', datetime.date(1985, 6, 27), 5274976),
#  ('Hockenheimring', 'German Grand Prix', datetime.date(2014, 7, 20), 'Rosberg', datetime.date(1985, 6, 27), 5622914),
#  ('Autódromo José Carlos Pace', 'Brazilian Grand Prix', datetime.date(2014, 11, 9), 'Rosberg', datetime.date(1985, 6, 27), 5402555),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2015, 5, 10), 'Rosberg', datetime.date(1985, 6, 27), 6072555),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2015, 5, 24), 'Rosberg', datetime.date(1985, 6, 27), 6558420),
#  ('Red Bull Ring', 'Austrian Grand Prix', datetime.date(2015, 6, 21), 'Rosberg', datetime.date(1985, 6, 27), 5416930),
#  ('Autódromo Hermanos Rodríguez', 'Mexican Grand Prix', datetime.date(2015, 11, 1), 'Rosberg', datetime.date(1985, 6, 27), 6155038),
#  ('Autódromo José Carlos Pace', 'Brazilian Grand Prix', datetime.date(2015, 11, 15), 'Rosberg', datetime.date(1985, 6, 27), 5469090),
#  ('Yas Marina Circuit', 'Abu Dhabi Grand Prix', datetime.date(2015, 11, 29), 'Rosberg', datetime.date(1985, 6, 27), 5910175),
#  ('Albert Park Grand Prix Circuit', 'Australian Grand Prix', datetime.date(2016, 3, 20), 'Rosberg', datetime.date(1985, 6, 27), 6495565),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2016, 4, 3), 'Rosberg', datetime.date(1985, 6, 27), 5614696),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2016, 4, 17), 'Rosberg', datetime.date(1985, 6, 27), 5933891),
#  ('Sochi Autodrom', 'Russian Grand Prix', datetime.date(2016, 5, 1), 'Rosberg', datetime.date(1985, 6, 27), 5561997),
#  ('Baku City Circuit', 'European Grand Prix', datetime.date(2016, 6, 19), 'Rosberg', datetime.date(1985, 6, 27), 5572366),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2016, 9, 4), 'Rosberg', datetime.date(1985, 6, 27), 4648089),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2016, 9, 18), 'Rosberg', datetime.date(1985, 6, 27), 6948950),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2016, 10, 9), 'Rosberg', datetime.date(1985, 6, 27), 5203333),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2013, 6, 9), 'Vettel', datetime.date(1987, 7, 3), 5529143),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2015, 3, 29), 'Vettel', datetime.date(1987, 7, 3), 6065793),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2013, 3, 24), 'Vettel', datetime.date(1987, 7, 3), 5936681),
#  ('Buddh International Circuit', 'Indian Grand Prix', datetime.date(2012, 10, 28), 'Vettel', datetime.date(1987, 7, 3), 5470744),
#  ('Valencia Street Circuit', 'European Grand Prix', datetime.date(2010, 6, 27), 'Vettel', datetime.date(1987, 7, 3), 6029571),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2017, 4, 16), 'Vettel', datetime.date(1987, 7, 3), 5633374),
#  ('Korean International Circuit', 'Korean Grand Prix', datetime.date(2012, 10, 14), 'Vettel', datetime.date(1987, 7, 3), 5788651),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2013, 10, 13), 'Vettel', datetime.date(1987, 7, 3), 5209301),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2010, 10, 10), 'Vettel', datetime.date(1987, 7, 3), 5427323),
#  ('Korean International Circuit', 'Korean Grand Prix', datetime.date(2013, 10, 6), 'Vettel', datetime.date(1987, 7, 3), 6193701),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2013, 9, 22), 'Vettel', datetime.date(1987, 7, 3), 7153132),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2013, 9, 8), 'Vettel', datetime.date(1987, 7, 3), 4713352),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2013, 8, 25), 'Vettel', datetime.date(1987, 7, 3), 5022196),
#  ('Nürburgring', 'German Grand Prix', datetime.date(2013, 7, 7), 'Vettel', datetime.date(1987, 7, 3), 6074711),
#  ('Albert Park Grand Prix Circuit', 'Australian Grand Prix', datetime.date(2017, 3, 26), 'Vettel', datetime.date(1987, 7, 3), 5051672),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2013, 4, 21), 'Vettel', datetime.date(1987, 7, 3), 5760498),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2012, 10, 7), 'Vettel', datetime.date(1987, 7, 3), 5336242),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2015, 7, 26), 'Vettel', datetime.date(1987, 7, 3), 6369985),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2012, 9, 23), 'Vettel', datetime.date(1987, 7, 3), 7226144),
#  ('Bahrain International Circuit', 'Bahrain Grand Prix', datetime.date(2012, 4, 22), 'Vettel', datetime.date(1987, 7, 3), 5710990),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2015, 9, 20), 'Vettel', datetime.date(1987, 7, 3), 7282118),
#  ('Buddh International Circuit', 'Indian Grand Prix', datetime.date(2011, 10, 30), 'Vettel', datetime.date(1987, 7, 3), 5435002),
#  ('Korean International Circuit', 'Korean Grand Prix', datetime.date(2011, 10, 16), 'Vettel', datetime.date(1987, 7, 3), 5881994),
#  ('Marina Bay Street Circuit', 'Singapore Grand Prix', datetime.date(2011, 9, 25), 'Vettel', datetime.date(1987, 7, 3), 7146757),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2010, 4, 4), 'Vettel', datetime.date(1987, 7, 3), 5628412),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2017, 5, 28), 'Vettel', datetime.date(1987, 7, 3), 6284340),
#  ('Yas Marina Circuit', 'Abu Dhabi Grand Prix', datetime.date(2009, 11, 1), 'Vettel', datetime.date(1987, 7, 3), 5643414),
#  ('Suzuka Circuit', 'Japanese Grand Prix', datetime.date(2009, 10, 4), 'Vettel', datetime.date(1987, 7, 3), 5300443),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2017, 7, 30), 'Vettel', datetime.date(1987, 7, 3), 5986713),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2011, 9, 11), 'Vettel', datetime.date(1987, 7, 3), 4846172),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2011, 8, 28), 'Vettel', datetime.date(1987, 7, 3), 5204893),
#  ('Silverstone Circuit', 'British Grand Prix', datetime.date(2009, 6, 21), 'Vettel', datetime.date(1987, 7, 3), 4969328),
#  ('Valencia Street Circuit', 'European Grand Prix', datetime.date(2011, 6, 26), 'Vettel', datetime.date(1987, 7, 3), 5976169),
#  ('Circuit de Monaco', 'Monaco Grand Prix', datetime.date(2011, 5, 29), 'Vettel', datetime.date(1987, 7, 3), 7778373),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2011, 5, 22), 'Vettel', datetime.date(1987, 7, 3), 5943301),
#  ('Istanbul Park', 'Turkish Grand Prix', datetime.date(2011, 5, 8), 'Vettel', datetime.date(1987, 7, 3), 5417558),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2011, 4, 10), 'Vettel', datetime.date(1987, 7, 3), 5859832),
#  ('Shanghai International Circuit', 'Chinese Grand Prix', datetime.date(2009, 4, 19), 'Vettel', datetime.date(1987, 7, 3), 7063485),
#  ('Autodromo Nazionale di Monza', 'Italian Grand Prix', datetime.date(2008, 9, 14), 'Vettel', datetime.date(1987, 7, 3), 5207494),
#  ('Albert Park Grand Prix Circuit', 'Australian Grand Prix', datetime.date(2011, 3, 27), 'Vettel', datetime.date(1987, 7, 3), 5370259),
#  ('Autódromo José Carlos Pace', 'Brazilian Grand Prix', datetime.date(2013, 11, 24), 'Vettel', datetime.date(1987, 7, 3), 5556300),
#  ('Circuit of the Americas', 'United States Grand Prix', datetime.date(2013, 11, 17), 'Vettel', datetime.date(1987, 7, 3), 5957148),
#  ('Yas Marina Circuit', 'Abu Dhabi Grand Prix', datetime.date(2013, 11, 3), 'Vettel', datetime.date(1987, 7, 3), 5886106),
#  ('Buddh International Circuit', 'Indian Grand Prix', datetime.date(2013, 10, 27), 'Vettel', datetime.date(1987, 7, 3), 5472187),
#  ('Yas Marina Circuit', 'Abu Dhabi Grand Prix', datetime.date(2010, 11, 14), 'Vettel', datetime.date(1987, 7, 3), 5976837),
#  ('Autódromo José Carlos Pace', 'Brazilian Grand Prix', datetime.date(2010, 11, 7), 'Vettel', datetime.date(1987, 7, 3), 5591803),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2016, 10, 2), 'Ricciardo', datetime.date(1989, 7, 1), 5832776),
#  ('Circuit de Spa-Francorchamps', 'Belgian Grand Prix', datetime.date(2014, 8, 24), 'Ricciardo', datetime.date(1989, 7, 1), 5076556),
#  ('Hungaroring', 'Hungarian Grand Prix', datetime.date(2014, 7, 27), 'Ricciardo', datetime.date(1989, 7, 1), 6785058),
#  ('Circuit Gilles Villeneuve', 'Canadian Grand Prix', datetime.date(2014, 6, 8), 'Ricciardo', datetime.date(1989, 7, 1), 5952830),
#  ('Baku City Circuit', 'Azerbaijan Grand Prix', datetime.date(2017, 6, 25), 'Ricciardo', datetime.date(1989, 7, 1), 7435573),
#  ('Sochi Autodrom', 'Russian Grand Prix', datetime.date(2017, 4, 30), 'Bottas', datetime.date(1989, 8, 28), 5288743),
#  ('Red Bull Ring', 'Austrian Grand Prix', datetime.date(2017, 7, 9), 'Bottas', datetime.date(1989, 8, 28), 4908523),
#  ('Sepang International Circuit', 'Malaysian Grand Prix', datetime.date(2017, 10, 1), 'Verstappen', datetime.date(1997, 9, 30), 5401290),
#  ('Circuit de Barcelona-Catalunya', 'Spanish Grand Prix', datetime.date(2016, 5, 15), 'Verstappen', datetime.date(1997, 9, 30), 6100017)]

# %% [markdown]
# ## 3. Describe the query using EXPLAIN ANALYZE with at least 5 lines of text. Answer at least the following

# %%
# %%sql
# EXPLAIN ANALYSE
# SELECT
# circuits.name AS Circuit_Name,
# races.name AS race_name, races.date AS race_date,
# drivers.surname AS driver_surname, drivers.dob AS driver_birthdate,
# results.milliseconds AS tracktime_ms FROM results
# JOIN drivers ON drivers.driverid = results.driverid AND drivers.dob > '1980-03-19' AND results.position = 1
# JOIN races ON races.raceid = results.raceid
# JOIN circuits ON circuits.circuitid = races.circuitid
# ORDER BY drivers.dob;
# Out:
# 21 rows affected.
# [('Sort  (cost=786.85..787.02 rows=68 width=62) (actual time=16.107..16.122 rows=184 loops=1)',),
#  ('  Sort Key: drivers.dob',),
#  ('  Sort Method: quicksort  Memory: 50kB',),
#  ('  ->  Nested Loop  (cost=25.67..784.78 rows=68 width=62) (actual time=0.329..15.880 rows=184 loops=1)',),
#  ('        ->  Nested Loop  (cost=25.53..772.81 rows=68 width=50) (actual time=0.316..15.485 rows=184 loops=1)',),
#  ('              ->  Hash Join  (cost=25.25..746.50 rows=68 width=27) (actual time=0.277..10.842 rows=184 loops=1)',),
#  ('                    Hash Cond: (results.driverid = drivers.driverid)',),
#  ('                    ->  Seq Scan on results  (cost=0.00..708.96 rows=974 width=24) (actual time=0.036..10.367 rows=974 loops=1)',),
#  ('                          Filter: ("position" = 1)',),
#  ('                          Rows Removed by Filter: 22703',),
#  ('                    ->  Hash  (cost=24.51..24.51 rows=59 width=19) (actual time=0.220..0.220 rows=60 loops=1)',),
#  ('                          Buckets: 1024  Batches: 1  Memory Usage: 12kB',),
#  ('                          ->  Seq Scan on drivers  (cost=0.00..24.51 rows=59 width=19) (actual time=0.009..0.197 rows=60 loops=1)',),
#  ("                                Filter: (dob > '1980-03-19'::date)",),
#  ('                                Rows Removed by Filter: 781',),
#  ('              ->  Index Scan using idx_17199_primary on races  (cost=0.28..0.39 rows=1 width=39) (actual time=0.002..0.002 rows=1 loops=184)',),
#  ('                    Index Cond: (raceid = results.raceid)',),
#  ('        ->  Index Scan using idx_17102_primary on circuits  (cost=0.14..0.18 rows=1 width=28) (actual time=0.001..0.001 rows=1 loops=184)',),
#  ('              Index Cond: (circuitid = races.circuitid)',),
#  ('Planning time: 0.790 ms',),
#  ('Execution time: 22.676 ms',)]

# %% [markdown]
# Running the Explain command plans how it will execute the queries. It will check the time it will take and if they is room for improvements. The Analyse command runs the querier and outputs the result above.
#
# At the bottom we can see how long the planning took (0.79 ms) and how long it took to execute the query (22.676 ms). It explains all the operations the query had to go through to give us our desired result. It had to sort the table using quicksort. It had to loop through the tables. The tables had to be joined together. It had to consider indexing options for both races and circuits, using the primary indexing. We had to filter using their driver's birthdate and remove everyone above 38 years of age. There's a total of 10 calls.

# %% [markdown]
# ## 4. Create a materialized view of your query. Using EXPLAIN ANALYZE try to query the view. Write at least 5 lines of text explaining what's going on and why the query execution time changed

# %%
# %%sql CREATE MATERIALIZED VIEW race_winners_cache AS
# SELECT circuits.name AS Circuit_Name,
# races.name AS race_name, races.date AS race_date,
# drivers.surname AS driver_surname, drivers.dob AS driver_birthdate,
# results.milliseconds AS tracktime_ms FROM results
# JOIN drivers ON drivers.driverid = results.driverid AND drivers.dob > '1980-03-19' AND results.position = 1
# JOIN races ON races.raceid = results.raceid
# JOIN circuits ON circuits.circuitid = races.circuitid
# ORDER BY drivers.dob;
# Out:
# 184 rows affected.
# []

# %%
# %sql EXPLAIN ANALYZE SELECT * FROM race_winners_cache
# Out:
# 3 rows affected.
# [('Seq Scan on race_winners_cache  (cost=0.00..4.84 rows=184 width=65) (actual time=0.013..0.039 rows=184 loops=1)',),
#  ('Planning time: 0.222 ms',),
#  ('Execution time: 0.075 ms',)]

# %% [markdown]
# We can see the both planning and execution times are much faster than in the previous Explain Anaylse. Unlike the previous task, we only run a single Seq Scan now. This is because of the materialised view, which is a cached version of a normal view. We basically started off caching a view of the query and to get everything from this view, we just need to loop through it once, instead of having to create the view first. This make it much faster to analyse data. The disadvantage however, is the fact that it is a cached version of our data after all. If the original data where to get updated - we would still be operating on the old data.
